# %% [markdown]
# # DATA ANALSYSIS
#
# ### Counting number of black and white and colour pictures in the data set

# %%
import cv2
from os import listdir
from os.path import isfile, join


onlyfiles = ['../../data/images/' + f for f in listdir('../../data/images') if isfile(join('../../data/images', f))]

d = {}
for f in onlyfiles:
    im = cv2.imread(f, cv2.IMREAD_UNCHANGED)
    if str(im.shape) not in d.keys():
        d[str(im.shape)] = 1
    else:
        d[str(im.shape)] += 1
d
# Out:
# {'(128, 128, 3)': 18578, '(128, 128)': 1422}

# %% [markdown]
# ### Occurrences of classes

# %%
import matplotlib.pyplot as plt
from matplotlib.pyplot import figure

# List of classes
x = ["baby", "bird", "car", "clouds", "dog", "female", "flower", "male", "night", "people", "portrait", "river", "sea", "tree"]

# List of occurrences
y = [95, 360, 319, 1095, 448, 3227, 761, 2979, 598, 6403, 1910, 120, 173, 525]

figure(figsize = (10,5), dpi = 150)
plt.bar(x,y, color = '#008080')
plt.xticks(rotation = 45, ha = 'right')
plt.xlabel('Classes')
plt.ylabel('Occurrences')
# Out:
# Text(0, 0.5, 'Occurrences')

# %% [markdown]
# ### Counting number of classes for each image

# %%
import cv2
from os import listdir
from os.path import isfile, join
import re


onlyfiles = [int(re.sub("[^0-9]", "", f)) for f in listdir('../../data/images') if isfile(join('../../data/images', f))]
onlyfiles.sort()
d = {}
annotations = ['../../data/annotations/' + f for f in listdir('../../data/annotations') if isfile(join('../../data/annotations', f))]
for item in onlyfiles:
    d[item] = 0
    for annotation in annotations:
        with open(annotation, 'r') as f:
            for line in f.readlines():
                if str(item) == line.strip():
                    d[item] += 1

d
# Out:
# {1: 3,
#  2: 0,
#  3: 0,
#  4: 2,
#  5: 2,
#  6: 0,
#  7: 2,
#  8: 0,
#  9: 0,
#  10: 0,
#  11: 2,
#  12: 3,
#  13: 1,
#  14: 0,
#  15: 2,
#  16: 2,
#  17: 0,
#  18: 0,
#  19: 0,
#  20: 0,
#  21: 1,
#  22: 0,
#  23: 0,
#  24: 2,
#  25: 1,
#  26: 3,
#  27: 0,
#  28: 1,
#  29: 0,
#  30: 0,
#  31: 1,
#  32: 2,
#  33: 1,
#  34: 0,
#  35: 0,
#  36: 1,
#  37: 2,
#  38: 0,
#  39: 4,
#  40: 0,
#  41: 3,
#  42: 0,
#  43: 1,
#  44: 1,
#  45: 1,
#  46: 0,
#  47: 1,
#  48: 0,
#  49: 3,
#  50: 3,
#  51: 2,
#  52: 0,
#  53: 0,
#  54: 0,
#  55: 3,
#  56: 1,
#  57: 0,
#  58: 0,
#  59: 0,
#  60: 1,
#  61: 0,
#  62: 0,
#  63: 0,
#  64: 0,
#  65: 0,
#  66: 0,
#  67: 3,
#  68: 1,
#  69: 0,
#  70: 0,
#  71: 0,
#  72: 1,
#  73: 1,
#  74: 0,
#  75: 3,
#  76: 1,
#  77: 2,
#  78: 0,
#  79: 1,
#  80: 1,
#  81: 3,
#  82: 0,
#  83: 2,
#  84: 0,
#  85: 1,
#  86: 3,
#  87: 1,
#  88: 1,
#  89: 1,
#  90: 0,
#  91: 2,
#  92: 1,
#  93: 1,
#  94: 0,
#  95: 1,
#  96: 1,
#  97: 1,
#  98: 3,
#  99: 3,
#  100: 2,
#  101: 1,
#  102: 0,
#  103: 1,
#  104: 3,
#  105: 3,
#  106: 1,
#  107: 0,
#  108: 0,
#  109: 0,
#  110: 3,
#  111: 0,
#  112: 1,
#  113: 1,
#  114: 1,
#  115: 0,
#  116: 1,
#  117: 0,
#  118: 0,
#  119: 1,
#  120: 0,
#  121: 1,
#  122: 0,
#  123: 1,
#  124: 2,
#  125: 1,
#  126: 3,
#  127: 0,
#  128: 0,
#  129: 1,
#  130: 1,
#  131: 0,
#  132: 0,
#  133: 0,
#  134: 3,
#  135: 1,
#  136: 2,
#  137: 1,
#  138: 0,
#  139: 0,
#  140: 2,
#  141: 2,
#  142: 3,
#  143: 0,
#  144: 2,
#  145: 0,
#  146: 0,
#  147: 1,
#  148: 0,
#  149: 0,
#  150: 0,
#  151: 0,
#  152: 3,
#  153: 3,
#  154: 1,
#  155: 3,
#  156: 0,
#  157: 0,
#  158: 1,
#  159: 1,
#  160: 0,
#  161: 0,
#  162: 0,
#  163: 0,
#  164: 1,
#  165: 4,
#  166: 1,
#  167: 0,
#  168: 3,
#  169: 0,
#  170: 1,
#  171: 0,
#  172: 2,
#  173: 1,
#  174: 0,
#  175: 1,
#  176: 4,
#  177: 3,
#  178: 1,
#  179: 1,
#  180: 0,
#  181: 3,
#  182: 0,
#  183: 3,
#  184: 1,
#  185: 3,
#  186: 0,
#  187: 1,
#  188: 0,
#  189: 1,
#  190: 1,
#  191: 1,
#  192: 0,
#  193: 0,
#  194: 0,
#  195: 0,
#  196: 0,
#  197: 3,
#  198: 1,
#  199: 0,
#  200: 3,
#  201: 0,
#  202: 1,
#  203: 0,
#  204: 1,
#  205: 0,
#  206: 1,
#  207: 0,
#  208: 1,
#  209: 3,
#  210: 3,
#  211: 1,
#  212: 3,
#  213: 3,
#  214: 0,
#  215: 3,
#  216: 2,
#  217: 0,
#  218: 0,
#  219: 1,
#  220: 0,
#  221: 1,
#  222: 2,
#  223: 2,
#  224: 0,
#  225: 0,
#  226: 0,
#  227: 0,
#  228: 1,
#  229: 4,
#  230: 2,
#  231: 2,
#  232: 0,
#  233: 2,
#  234: 0,
#  235: 0,
#  236: 0,
#  237: 2,
#  238: 2,
#  239: 2,
#  240: 0,
#  241: 1,
#  242: 0,
#  243: 2,
#  244: 3,
#  245: 0,
#  246: 0,
#  247: 1,
#  248: 0,
#  249: 1,
#  250: 0,
#  251: 1,
#  252: 1,
#  253: 2,
#  254: 2,
#  255: 0,
#  256: 0,
#  257: 3,
#  258: 2,
#  259: 0,
#  260: 3,
#  261: 1,
#  262: 0,
#  263: 3,
#  264: 2,
#  265: 1,
#  266: 0,
#  267: 0,
#  268: 0,
#  269: 0,
#  270: 2,
#  271: 3,
#  272: 0,
#  273: 4,
#  274: 0,
#  275: 0,
#  276: 1,
#  277: 1,
#  278: 1,
#  279: 2,
#  280: 0,
#  281: 0,
#  282: 0,
#  283: 3,
#  284: 2,
#  285: 0,
#  286: 0,
#  287: 0,
#  288: 1,
#  289: 0,
#  290: 0,
#  291: 0,
#  292: 0,
#  293: 0,
#  294: 2,
#  295: 1,
#  296: 1,
#  297: 0,
#  298: 1,
#  299: 0,
#  300: 0,
#  301: 3,
#  302: 1,
#  303: 1,
#  304: 0,
#  305: 0,
#  306: 1,
#  307: 1,
#  308: 1,
#  309: 1,
#  310: 1,
#  311: 1,
#  312: 2,
#  313: 3,
#  314: 0,
#  315: 1,
#  316: 2,
#  317: 1,
#  318: 0,
#  319: 0,
#  320: 0,
#  321: 2,
#  322: 3,
#  323: 1,
#  324: 0,
#  325: 0,
#  326: 1,
#  327: 1,
#  328: 0,
#  329: 1,
#  330: 3,
#  331: 0,
#  332: 3,
#  333: 3,
#  334: 3,
#  335: 0,
#  336: 1,
#  337: 1,
#  338: 2,
#  339: 1,
#  340: 0,
#  341: 0,
#  342: 3,
#  343: 1,
#  344: 0,
#  345: 1,
#  346: 3,
#  347: 1,
#  348: 0,
#  349: 0,
#  350: 0,
#  351: 0,
#  352: 0,
#  353: 3,
#  354: 3,
#  355: 0,
#  356: 1,
#  357: 0,
#  358: 0,
#  359: 3,
#  360: 1,
#  361: 2,
#  362: 1,
#  363: 3,
#  364: 0,
#  365: 3,
#  366: 0,
#  367: 1,
#  368: 1,
#  369: 0,
#  370: 0,
#  371: 0,
#  372: 1,
#  373: 1,
#  374: 3,
#  375: 3,
#  376: 0,
#  377: 0,
#  378: 1,
#  379: 1,
#  380: 0,
#  381: 0,
#  382: 0,
#  383: 3,
#  384: 0,
#  385: 2,
#  386: 3,
#  387: 2,
#  388: 0,
#  389: 2,
#  390: 3,
#  391: 2,
#  392: 1,
#  393: 0,
#  394: 3,
#  395: 1,
#  396: 2,
#  397: 3,
#  398: 3,
#  399: 2,
#  400: 1,
#  401: 1,
#  402: 1,
#  403: 1,
#  404: 3,
#  405: 2,
#  406: 0,
#  407: 3,
#  408: 0,
#  409: 1,
#  410: 1,
#  411: 0,
#  412: 0,
#  413: 1,
#  414: 0,
#  415: 2,
#  416: 1,
#  417: 1,
#  418: 0,
#  419: 0,
#  420: 1,
#  421: 2,
#  422: 2,
#  423: 2,
#  424: 3,
#  425: 0,
#  426: 1,
#  427: 1,
#  428: 0,
#  429: 1,
#  430: 0,
#  431: 0,
#  432: 3,
#  433: 3,
#  434: 1,
#  435: 3,
#  436: 2,
#  437: 0,
#  438: 0,
#  439: 0,
#  440: 0,
#  441: 0,
#  442: 0,
#  443: 1,
#  444: 0,
#  445: 0,
#  446: 1,
#  447: 0,
#  448: 0,
#  449: 0,
#  450: 3,
#  451: 3,
#  452: 0,
#  453: 1,
#  454: 1,
#  455: 0,
#  456: 0,
#  457: 3,
#  458: 0,
#  459: 1,
#  460: 0,
#  461: 3,
#  462: 1,
#  463: 0,
#  464: 1,
#  465: 3,
#  466: 1,
#  467: 0,
#  468: 3,
#  469: 0,
#  470: 0,
#  471: 0,
#  472: 3,
#  473: 1,
#  474: 3,
#  475: 0,
#  476: 1,
#  477: 0,
#  478: 1,
#  479: 0,
#  480: 3,
#  481: 0,
#  482: 0,
#  483: 2,
#  484: 0,
#  485: 1,
#  486: 0,
#  487: 2,
#  488: 0,
#  489: 2,
#  490: 0,
#  491: 0,
#  492: 0,
#  493: 1,
#  494: 0,
#  495: 3,
#  496: 0,
#  497: 0,
#  498: 2,
#  499: 1,
#  500: 1,
#  501: 0,
#  502: 1,
#  503: 0,
#  504: 2,
#  505: 1,
#  506: 1,
#  507: 2,
#  508: 3,
#  509: 0,
#  510: 1,
#  511: 2,
#  512: 3,
#  513: 3,
#  514: 0,
#  515: 0,
#  516: 0,
#  517: 1,
#  518: 0,
#  519: 0,
#  520: 1,
#  521: 1,
#  522: 2,
#  523: 2,
#  524: 2,
#  525: 0,
#  526: 1,
#  527: 0,
#  528: 0,
#  529: 2,
#  530: 2,
#  531: 0,
#  532: 0,
#  533: 0,
#  534: 0,
#  535: 1,
#  536: 0,
#  537: 0,
#  538: 2,
#  539: 0,
#  540: 0,
#  541: 0,
#  542: 3,
#  543: 3,
#  544: 0,
#  545: 2,
#  546: 0,
#  547: 2,
#  548: 3,
#  549: 2,
#  550: 0,
#  551: 3,
#  552: 0,
#  553: 1,
#  554: 0,
#  555: 3,
#  556: 3,
#  557: 0,
#  558: 0,
#  559: 0,
#  560: 2,
#  561: 0,
#  562: 0,
#  563: 0,
#  564: 0,
#  565: 0,
#  566: 2,
#  567: 3,
#  568: 0,
#  569: 0,
#  570: 0,
#  571: 2,
#  572: 1,
#  573: 0,
#  574: 1,
#  575: 1,
#  576: 0,
#  577: 1,
#  578: 0,
#  579: 0,
#  580: 2,
#  581: 0,
#  582: 0,
#  583: 1,
#  584: 0,
#  585: 2,
#  586: 3,
#  587: 1,
#  588: 2,
#  589: 0,
#  590: 0,
#  591: 3,
#  592: 2,
#  593: 3,
#  594: 1,
#  595: 1,
#  596: 0,
#  597: 0,
#  598: 1,
#  599: 1,
#  600: 0,
#  601: 0,
#  602: 2,
#  603: 2,
#  604: 3,
#  605: 0,
#  606: 1,
#  607: 2,
#  608: 0,
#  609: 0,
#  610: 2,
#  611: 0,
#  612: 0,
#  613: 0,
#  614: 0,
#  615: 0,
#  616: 1,
#  617: 0,
#  618: 1,
#  619: 1,
#  620: 3,
#  621: 1,
#  622: 0,
#  623: 3,
#  624: 0,
#  625: 1,
#  626: 3,
#  627: 1,
#  628: 0,
#  629: 0,
#  630: 2,
#  631: 0,
#  632: 1,
#  633: 3,
#  634: 0,
#  635: 3,
#  636: 3,
#  637: 3,
#  638: 2,
#  639: 0,
#  640: 4,
#  641: 0,
#  642: 3,
#  643: 0,
#  644: 3,
#  645: 1,
#  646: 1,
#  647: 1,
#  648: 1,
#  649: 0,
#  650: 0,
#  651: 0,
#  652: 0,
#  653: 1,
#  654: 1,
#  655: 0,
#  656: 1,
#  657: 1,
#  658: 1,
#  659: 0,
#  660: 3,
#  661: 0,
#  662: 0,
#  663: 0,
#  664: 1,
#  665: 0,
#  666: 5,
#  667: 0,
#  668: 3,
#  669: 0,
#  670: 3,
#  671: 1,
#  672: 2,
#  673: 0,
#  674: 0,
#  675: 1,
#  676: 1,
#  677: 1,
#  678: 0,
#  679: 1,
#  680: 2,
#  681: 3,
#  682: 0,
#  683: 0,
#  684: 1,
#  685: 1,
#  686: 0,
#  687: 0,
#  688: 1,
#  689: 2,
#  690: 0,
#  691: 1,
#  692: 0,
#  693: 2,
#  694: 0,
#  695: 1,
#  696: 1,
#  697: 0,
#  698: 3,
#  699: 0,
#  700: 2,
#  701: 3,
#  702: 1,
#  703: 0,
#  704: 0,
#  705: 0,
#  706: 1,
#  707: 3,
#  708: 0,
#  709: 0,
#  710: 1,
#  711: 0,
#  712: 1,
#  713: 1,
#  714: 0,
#  715: 1,
#  716: 1,
#  717: 0,
#  718: 0,
#  719: 2,
#  720: 0,
#  721: 2,
#  722: 0,
#  723: 0,
#  724: 0,
#  725: 3,
#  726: 0,
#  727: 0,
#  728: 1,
#  729: 1,
#  730: 1,
#  731: 0,
#  732: 1,
#  733: 0,
#  734: 0,
#  735: 3,
#  736: 0,
#  737: 2,
#  738: 1,
#  739: 0,
#  740: 0,
#  741: 0,
#  742: 0,
#  743: 1,
#  744: 3,
#  745: 0,
#  746: 0,
#  747: 2,
#  748: 1,
#  749: 1,
#  750: 1,
#  751: 1,
#  752: 1,
#  753: 2,
#  754: 0,
#  755: 1,
#  756: 3,
#  757: 1,
#  758: 1,
#  759: 1,
#  760: 1,
#  761: 3,
#  762: 2,
#  763: 0,
#  764: 0,
#  765: 3,
#  766: 0,
#  767: 1,
#  768: 0,
#  769: 0,
#  770: 0,
#  771: 0,
#  772: 0,
#  773: 0,
#  774: 3,
#  775: 0,
#  776: 2,
#  777: 2,
#  778: 0,
#  779: 0,
#  780: 3,
#  781: 1,
#  782: 0,
#  783: 2,
#  784: 0,
#  785: 0,
#  786: 3,
#  787: 1,
#  788: 0,
#  789: 3,
#  790: 0,
#  791: 0,
#  792: 0,
#  793: 3,
#  794: 1,
#  795: 0,
#  796: 1,
#  797: 1,
#  798: 0,
#  799: 0,
#  800: 0,
#  801: 0,
#  802: 2,
#  803: 0,
#  804: 2,
#  805: 1,
#  806: 2,
#  807: 0,
#  808: 1,
#  809: 3,
#  810: 5,
#  811: 0,
#  812: 0,
#  813: 2,
#  814: 1,
#  815: 0,
#  816: 2,
#  817: 0,
#  818: 2,
#  819: 3,
#  820: 1,
#  821: 1,
#  822: 3,
#  823: 2,
#  824: 0,
#  825: 0,
#  826: 0,
#  827: 3,
#  828: 0,
#  829: 1,
#  830: 0,
#  831: 0,
#  832: 1,
#  833: 1,
#  834: 1,
#  835: 3,
#  836: 0,
#  837: 3,
#  838: 0,
#  839: 2,
#  840: 3,
#  841: 2,
#  842: 0,
#  843: 2,
#  844: 3,
#  845: 0,
#  846: 0,
#  847: 0,
#  848: 2,
#  849: 1,
#  850: 1,
#  851: 1,
#  852: 2,
#  853: 1,
#  854: 3,
#  855: 0,
#  856: 3,
#  857: 0,
#  858: 0,
#  859: 0,
#  860: 0,
#  861: 2,
#  862: 3,
#  863: 0,
#  864: 3,
#  865: 1,
#  866: 1,
#  867: 1,
#  868: 3,
#  869: 0,
#  870: 0,
#  871: 1,
#  872: 0,
#  873: 2,
#  874: 3,
#  875: 3,
#  876: 0,
#  877: 2,
#  878: 0,
#  879: 0,
#  880: 0,
#  881: 2,
#  882: 0,
#  883: 1,
#  884: 2,
#  885: 0,
#  886: 1,
#  887: 0,
#  888: 4,
#  889: 0,
#  890: 2,
#  891: 0,
#  892: 2,
#  893: 1,
#  894: 0,
#  895: 3,
#  896: 2,
#  897: 3,
#  898: 2,
#  899: 1,
#  900: 0,
#  901: 4,
#  902: 0,
#  903: 1,
#  904: 0,
#  905: 0,
#  906: 3,
#  907: 2,
#  908: 4,
#  909: 1,
#  910: 0,
#  911: 0,
#  912: 0,
#  913: 0,
#  914: 3,
#  915: 0,
#  916: 0,
#  917: 0,
#  918: 2,
#  919: 0,
#  920: 0,
#  921: 1,
#  922: 0,
#  923: 0,
#  924: 2,
#  925: 1,
#  926: 0,
#  927: 0,
#  928: 0,
#  929: 3,
#  930: 2,
#  931: 0,
#  932: 1,
#  933: 1,
#  934: 0,
#  935: 3,
#  936: 0,
#  937: 0,
#  938: 3,
#  939: 3,
#  940: 0,
#  941: 0,
#  942: 0,
#  943: 3,
#  944: 1,
#  945: 2,
#  946: 0,
#  947: 3,
#  948: 2,
#  949: 1,
#  950: 1,
#  951: 1,
#  952: 0,
#  953: 2,
#  954: 1,
#  955: 0,
#  956: 2,
#  957: 1,
#  958: 2,
#  959: 2,
#  960: 0,
#  961: 0,
#  962: 1,
#  963: 0,
#  964: 3,
#  965: 1,
#  966: 1,
#  967: 0,
#  968: 1,
#  969: 1,
#  970: 1,
#  971: 3,
#  972: 3,
#  973: 2,
#  974: 0,
#  975: 3,
#  976: 3,
#  977: 0,
#  978: 1,
#  979: 3,
#  980: 1,
#  981: 0,
#  982: 1,
#  983: 1,
#  984: 0,
#  985: 0,
#  986: 0,
#  987: 1,
#  988: 2,
#  989: 2,
#  990: 1,
#  991: 0,
#  992: 1,
#  993: 0,
#  994: 3,
#  995: 0,
#  996: 0,
#  997: 0,
#  998: 0,
#  999: 2,
#  1000: 1,
#  ...}

# %% [markdown]
# ### Grouping images by number of classes in it

# %%
import pandas as pd

df = pd.DataFrame.from_dict(d, orient='index')
df['classes'] = df[0]
df.groupby('classes').count()
# Out:
#             0
# classes
# 0        9824
# 1        4161
# 2        2388
# 3        3230
# 4         388
# 5           9
